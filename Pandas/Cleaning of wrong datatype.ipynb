# %% [markdown]
# ### Cleaning of wrong Datatype format

# %% [markdown]
# Dataset can be downloaded from [AutoInland Insurance Claim](https://zindi.africa/competitions/indabax-ghana-autoinland-vehicle-insurance-claim/data)

# %% [markdown]
# ![Autoin](indaba.png)

# %%
import pandas as pd 
data = pd.read_csv("C:/Users/DELL/Downloads/Projects/IndabaX/Train.csv")
data.head()
# Out:
#            ID Policy Start Date Policy End Date  Gender  Age  \
# 0  ID_0040R73        2010-05-14      2011-05-13    Male   30
# 1  ID_0046BNK        2010-11-29      2011-11-28  Female   79
# 2  ID_005QMC3        2010-03-21      2011-03-20    Male   43
# 3  ID_0079OHW        2010-08-21      2011-08-20    Male    2
# 4  ID_00BRP63        2010-08-29      2010-12-31  Entity   20
#
#   First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 0             2010-05-14       1       Saloon              Black
# 1             2010-11-29       1         JEEP               Grey
# 2             2010-03-21       1       Saloon                Red
# 3             2010-08-21       1          NaN                NaN
# 4             2010-08-29       3          NaN                NaN
#
#   Subject_Car_Make LGA_Name  State  ProductName  target
# 0           TOYOTA      NaN    NaN  Car Classic       0
# 1           TOYOTA      NaN    NaN  Car Classic       1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12079 entries, 0 to 12078
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12079 non-null  object
#  1   Policy Start Date       12079 non-null  object
#  2   Policy End Date         12079 non-null  object
#  3   Gender                  11720 non-null  object
#  4   Age                     12079 non-null  int64
#  5   First Transaction Date  12079 non-null  object
#  6   No_Pol                  12079 non-null  int64
#  7   Car_Category            8341 non-null   object
#  8   Subject_Car_Colour      5117 non-null   object
#  9   Subject_Car_Make        9603 non-null   object
#  10  LGA_Name                5603 non-null   object
#  11  State                   5591 non-null   object
#  12  ProductName             12079 non-null  object
#  13  target                  12079 non-null  int64
# ...

# %% [markdown]
# ## Converting Date into the right format

# %%
## We are going to use the to_datetime()
data['Policy Start Date'] = pd.to_datetime(data['Policy Start Date'])

# %%
data.info()# checking for changes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12079 entries, 0 to 12078
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12079 non-null  object
#  1   Policy Start Date       12079 non-null  datetime64[ns]
#  2   Policy End Date         12079 non-null  object
#  3   Gender                  11720 non-null  object
#  4   Age                     12079 non-null  int64
#  5   First Transaction Date  12079 non-null  object
#  6   No_Pol                  12079 non-null  int64
#  7   Car_Category            8341 non-null   object
#  8   Subject_Car_Colour      5117 non-null   object
#  9   Subject_Car_Make        9603 non-null   object
#  10  LGA_Name                5603 non-null   object
#  11  State                   5591 non-null   object
#  12  ProductName             12079 non-null  object
#  13  target                  12079 non-null  int64
# ...

# %%
data['Policy End Date'] = pd.to_datetime(data['Policy End Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12079 entries, 0 to 12078
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12079 non-null  object
#  1   Policy Start Date       12079 non-null  datetime64[ns]
#  2   Policy End Date         12079 non-null  datetime64[ns]
#  3   Gender                  11720 non-null  object
#  4   Age                     12079 non-null  int64
#  5   First Transaction Date  12079 non-null  object
#  6   No_Pol                  12079 non-null  int64
#  7   Car_Category            8341 non-null   object
#  8   Subject_Car_Colour      5117 non-null   object
#  9   Subject_Car_Make        9603 non-null   object
#  10  LGA_Name                5603 non-null   object
#  11  State                   5591 non-null   object
#  12  ProductName             12079 non-null  object
#  13  target                  12079 non-null  int64
# ...

# %%
data.head()
# Out:
#            ID Policy Start Date Policy End Date  Gender  Age  \
# 0  ID_0040R73        2010-05-14      2011-05-13    Male   30
# 1  ID_0046BNK        2010-11-29      2011-11-28  Female   79
# 2  ID_005QMC3        2010-03-21      2011-03-20    Male   43
# 3  ID_0079OHW        2010-08-21      2011-08-20    Male    2
# 4  ID_00BRP63        2010-08-29      2010-12-31  Entity   20
#
#   First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 0             2010-05-14       1       Saloon              Black
# 1             2010-11-29       1         JEEP               Grey
# 2             2010-03-21       1       Saloon                Red
# 3             2010-08-21       1          NaN                NaN
# 4             2010-08-29       3          NaN                NaN
#
#   Subject_Car_Make LGA_Name  State  ProductName  target
# 0           TOYOTA      NaN    NaN  Car Classic       0
# 1           TOYOTA      NaN    NaN  Car Classic       1
# ...

# %% [markdown]
# ### Removing rows

# %%
data.dropna()
# Out:
#                ID Policy Start Date Policy End Date  Gender  Age  \
# 8      ID_00N7XT1        2010-07-06      2011-07-05  Female   71
# 22     ID_01ZY7FF        2010-08-07      2011-08-06    Male   30
# 24     ID_022U6TV        2010-10-28      2011-10-27    Male   40
# 26     ID_02DJWEN        2010-01-23      2011-01-16    Male   41
# 39     ID_03U3I31        2010-09-06      2011-09-05    Male   39
# ...           ...               ...             ...     ...  ...
# 12050  ID_ZWX4QUS        2010-03-19      2011-03-18    Male   59
# 12052  ID_ZX15LXQ        2010-06-28      2011-06-27    Male   70
# 12054  ID_ZXAI4LH        2010-11-16      2011-11-15    Male   33
# 12073  ID_ZZ5JOXU        2010-08-08      2011-08-07  Female   31
# 12078  ID_ZZWRIIE        2010-07-01      2011-06-30  Female   46
#
#       First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 8                 2010-07-06       2         JEEP              Black
# ...

# %%
data.shape
# Out:
# (12079, 14)

# %%
# data.dropna(inplace =True)
# data.shape

# %%
data.dropna(subset=['Car_Category'])

# %% [markdown]
# ## Filling in Missing Values

# %%
data.fillna(10)
# Out:
#                ID Policy Start Date Policy End Date  Gender  Age  \
# 0      ID_0040R73        2010-05-14      2011-05-13    Male   30
# 1      ID_0046BNK        2010-11-29      2011-11-28  Female   79
# 2      ID_005QMC3        2010-03-21      2011-03-20    Male   43
# 3      ID_0079OHW        2010-08-21      2011-08-20    Male    2
# 4      ID_00BRP63        2010-08-29      2010-12-31  Entity   20
# ...           ...               ...             ...     ...  ...
# 12074  ID_ZZA1SES        2010-05-25      2011-05-24  Female   30
# 12075  ID_ZZDAC3K        2010-10-03      2011-10-02  Female   59
# 12076  ID_ZZIU2XC        2010-10-10      2011-10-08    Male   34
# 12077  ID_ZZRQ1NF        2010-02-27      2011-02-26      10  120
# 12078  ID_ZZWRIIE        2010-07-01      2011-06-30  Female   46
#
#       First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 0                 2010-05-14       1       Saloon              Black
# ...

# %%
data.shape
# Out:
# (12079, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12079 entries, 0 to 12078
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12079 non-null  object
#  1   Policy Start Date       12079 non-null  datetime64[ns]
#  2   Policy End Date         12079 non-null  object
#  3   Gender                  11720 non-null  object
#  4   Age                     12079 non-null  int64
#  5   First Transaction Date  12079 non-null  object
#  6   No_Pol                  12079 non-null  int64
#  7   Car_Category            8341 non-null   object
#  8   Subject_Car_Colour      5117 non-null   object
#  9   Subject_Car_Make        9603 non-null   object
#  10  LGA_Name                5603 non-null   object
#  11  State                   5591 non-null   object
#  12  ProductName             12079 non-null  object
#  13  target                  12079 non-null  int64
# ...

# %% [markdown]
# ### Fixing Wrong Data

# %%
##
data['Age'].describe()
# Out:
# count    12079.000000
# mean        42.234539
# std         97.492565
# min      -6099.000000
# 25%         35.000000
# 50%         41.000000
# 75%         50.000000
# max        320.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### Replacing Values

# %%
data.loc[data['Age'] == -6099]
# Out:
#               ID Policy Start Date Policy End Date      Gender   Age  \
# 3427  ID_A3YN75Z        2010-10-02      2011-10-01  NOT STATED -6099
#
#      First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 3427             2010-10-02       1          NaN                NaN
#
#      Subject_Car_Make LGA_Name State ProductName  target
# 3427              NaN      NaN   NaN     CarSafe       0

# %%
data.loc[3427,'Age'] = 41

# %%
data['Age'].describe()
# Out:
# count    12079.000000
# mean        42.742860
# std         79.887058
# min      -5939.000000
# 25%         35.000000
# 50%         41.000000
# 75%         50.000000
# max        320.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### Removing rows

# %%
for x in data.index:
    if data.loc[x, "Age"] > 120:
        data.drop(x, inplace = True)

# %%
data['Age'].describe()
# Out:
# count    12062.000000
# mean        42.427624
# std         79.439239
# min      -5939.000000
# 25%         35.000000
# 50%         41.000000
# 75%         50.000000
# max        120.000000
# Name: Age, dtype: float64

# %%
for x in data.index: 
    if data.loc[x, 'Age'] <= 1:
        data.drop(x, inplace = True)

# %%
data['Age'].describe()
# Out:
# count    11815.000000
# mean        44.332967
# std         18.487254
# min          2.000000
# 25%         35.000000
# 50%         41.000000
# 75%         50.000000
# max        120.000000
# Name: Age, dtype: float64
